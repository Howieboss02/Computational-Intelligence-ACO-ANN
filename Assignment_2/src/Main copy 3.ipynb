# %%
import time
import matplotlib.pyplot as plt

from AntColonyOptimization import AntColonyOptimization
from GeneticAlgorithm import GeneticAlgorithm
from Maze import Maze
from PathSpecification import PathSpecification
from TSPData import TSPData

# %% [markdown]
# ### Part 1: The Travelling Robot Problem

# %%
# Please keep your parameters for the Genetic Algorithm easily changeable here
population_size = 1000
generations = 200
mutation_rate = 0.085
crossover_probability = 0.7
persist_file = "./../data/optimal_tsp"

# Setup optimization
tsp_data = TSPData.read_from_file(persist_file)
ga = GeneticAlgorithm(generations, population_size, mutation_rate, crossover_probability)

# Run optimzation and write to file

solution = ga.solve_tsp(tsp_data)
tsp_data.write_action_file(solution, "./../data/tsp_solution.txt")
# Out:
# Generation  1
# Length of the best route =  3107.0
# Generation  2
# Length of the best route =  2535.0
# Generation  3
# Length of the best route =  2535.0
# Generation  4
# Length of the best route =  3379.0
# Generation  5
# Length of the best route =  3379.0
# Generation  6
# Length of the best route =  3213.0
# Generation  7
# Length of the best route =  3363.0000000000005
# Generation  8
# Length of the best route =  3231.0
# Generation  9
# Length of the best route =  3107.0
# Generation  10
# Length of the best route =  3107.0
# Generation  11
# Length of the best route =  2933.0
# Generation  12
# Length of the best route =  2933.0
# Generation  13
# Length of the best route =  2685.0
# Generation  14
# Length of the best route =  2685.0
# Generation  15
# Length of the best route =  2679.0
# Generation  16
# Length of the best route =  2633.0
# Generation  17
# Length of the best route =  2621.0
# Generation  18
# Length of the best route =  2823.0
# Generation  19
# Length of the best route =  2779.0
# Generation  20
# Length of the best route =  2889.0
# Generation  21
# Length of the best route =  2879.0
# Generation  22
# Length of the best route =  2819.0
# Generation  23
# Length of the best route =  2819.0
# Generation  24
# Length of the best route =  2819.0
# Generation  25
# Length of the best route =  2705.0
# Generation  26
# Length of the best route =  2613.0
# Generation  27
# Length of the best route =  2613.0
# Generation  28
# Length of the best route =  2659.0
# Generation  29
# Length of the best route =  2629.0
# Generation  30
# Length of the best route =  2629.0
# Generation  31
# Length of the best route =  2563.0
# Generation  32
# Length of the best route =  2165.0
# Generation  33
# Length of the best route =  2165.0
# Generation  34
# Length of the best route =  2165.0
# Generation  35
# Length of the best route =  2261.0
# Generation  36
# Length of the best route =  2261.0
# Generation  37
# Length of the best route =  2081.0
# Generation  38
# Length of the best route =  2079.0
# Generation  39
# Length of the best route =  2173.0
# Generation  40
# Length of the best route =  2173.0
# Generation  41
# Length of the best route =  2173.0
# Generation  42
# Length of the best route =  2293.0
# Generation  43
# Length of the best route =  2187.0
# Generation  44
# Length of the best route =  2187.0
# Generation  45
# Length of the best route =  2187.0
# Generation  46
# Length of the best route =  2187.0
# Generation  47
# Length of the best route =  2187.0
# Generation  48
# Length of the best route =  2169.0
# Generation  49
# Length of the best route =  2047.0
# Generation  50
# Length of the best route =  1825.0000000000002
# Generation  51
# Length of the best route =  1825.0000000000002
# Generation  52
# Length of the best route =  1825.0000000000002
# Generation  53
# Length of the best route =  1825.0000000000002
# Generation  54
# Length of the best route =  2019.0
# Generation  55
# Length of the best route =  2183.0
# Generation  56
# Length of the best route =  2123.0
# Generation  57
# Length of the best route =  2123.0
# Generation  58
# Length of the best route =  2221.0
# Generation  59
# Length of the best route =  2195.0
# Generation  60
# Length of the best route =  2375.0
# Generation  61
# Length of the best route =  2307.0
# Generation  62
# Length of the best route =  2303.0
# Generation  63
# Length of the best route =  2377.0
# Generation  64
# Length of the best route =  2235.0
# Generation  65
# Length of the best route =  2235.0
# Generation  66
# Length of the best route =  2235.0
# Generation  67
# Length of the best route =  2325.0
# Generation  68
# Length of the best route =  2253.0
# Generation  69
# Length of the best route =  2351.0
# Generation  70
# Length of the best route =  2135.0
# Generation  71
# Length of the best route =  2038.9999999999998
# Generation  72
# Length of the best route =  1974.9999999999998
# Generation  73
# Length of the best route =  2038.9999999999998
# Generation  74
# Length of the best route =  2071.0
# Generation  75
# Length of the best route =  2127.0
# Generation  76
# Length of the best route =  2077.0
# Generation  77
# Length of the best route =  2183.0
# Generation  78
# Length of the best route =  2035.0
# Generation  79
# Length of the best route =  2035.0
# Generation  80
# Length of the best route =  2035.0
# Generation  81
# Length of the best route =  1869.0000000000002
# Generation  82
# Length of the best route =  1886.9999999999998
# Generation  83
# Length of the best route =  1741.0
# Generation  84
# Length of the best route =  1913.0
# Generation  85
# Length of the best route =  1809.0
# Generation  86
# Length of the best route =  1809.0
# Generation  87
# Length of the best route =  1780.9999999999998
# Generation  88
# Length of the best route =  1815.0000000000002
# Generation  89
# Length of the best route =  1693.0
# Generation  90
# Length of the best route =  1845.0
# Generation  91
# Length of the best route =  1807.0000000000002
# Generation  92
# Length of the best route =  1869.0000000000002
# Generation  93
# Length of the best route =  1869.0000000000002
# Generation  94
# Length of the best route =  1761.0
# Generation  95
# Length of the best route =  1697.0
# Generation  96
# Length of the best route =  1678.9999999999998
# Generation  97
# Length of the best route =  1804.9999999999998
# Generation  98
# Length of the best route =  1425.0
# Generation  99
# Length of the best route =  1425.0
# Generation  100
# Length of the best route =  1425.0
# Generation  101
# Length of the best route =  1425.0
# Generation  102
# Length of the best route =  1537.0
# Generation  103
# Length of the best route =  1523.0000000000002
# Generation  104
# Length of the best route =  1599.0
# Generation  105
# Length of the best route =  1599.0
# Generation  106
# Length of the best route =  1609.0
# Generation  107
# Length of the best route =  1689.0000000000002
# Generation  108
# Length of the best route =  1689.0000000000002
# Generation  109
# Length of the best route =  1529.0
# Generation  110
# Length of the best route =  1529.0
# Generation  111
# Length of the best route =  1551.0
# Generation  112
# Length of the best route =  1551.0
# Generation  113
# Length of the best route =  1535.0
# Generation  114
# Length of the best route =  1485.0
# Generation  115
# Length of the best route =  1459.0
# Generation  116
# Length of the best route =  1459.0
# Generation  117
# Length of the best route =  1455.0
# Generation  118
# Length of the best route =  1443.0
# Generation  119
# Length of the best route =  1421.0
# Generation  120
# Length of the best route =  1387.0
# Generation  121
# Length of the best route =  1449.0
# Generation  122
# Length of the best route =  1363.0
# Generation  123
# Length of the best route =  1395.0
# Generation  124
# Length of the best route =  1395.0
# Generation  125
# Length of the best route =  1395.0
# Generation  126
# Length of the best route =  1357.0
# Generation  127
# Length of the best route =  1347.0
# Generation  128
# Length of the best route =  1361.0
# Generation  129
# Length of the best route =  1339.0
# Generation  130
# Length of the best route =  1393.0
# Generation  131
# Length of the best route =  1393.0
# Generation  132
# Length of the best route =  1393.0
# Generation  133
# Length of the best route =  1393.0
# Generation  134
# Length of the best route =  1403.0
# Generation  135
# Length of the best route =  1415.0
# Generation  136
# Length of the best route =  1389.0
# Generation  137
# Length of the best route =  1389.0
# Generation  138
# Length of the best route =  1365.0
# Generation  139
# Length of the best route =  1393.0
# Generation  140
# Length of the best route =  1349.0
# Generation  141
# Length of the best route =  1383.0
# Generation  142
# Length of the best route =  1385.0
# Generation  143
# Length of the best route =  1393.0
# Generation  144
# Length of the best route =  1383.0
# Generation  145
# Length of the best route =  1395.0
# Generation  146
# Length of the best route =  1381.0
# Generation  147
# Length of the best route =  1377.0
# Generation  148
# Length of the best route =  1377.0
# Generation  149
# Length of the best route =  1363.0
# Generation  150
# Length of the best route =  1357.0
# Generation  151
# Length of the best route =  1389.0
# Generation  152
# Length of the best route =  1391.0
# Generation  153
# Length of the best route =  1391.0
# Generation  154
# Length of the best route =  1345.0
# Generation  155
# Length of the best route =  1345.0
# Generation  156
# Length of the best route =  1345.0
# Generation  157
# Length of the best route =  1335.0
# Generation  158
# Length of the best route =  1345.0
# Generation  159
# Length of the best route =  1329.0
# Generation  160
# Length of the best route =  1361.0
# Generation  161
# Length of the best route =  1367.0
# Generation  162
# Length of the best route =  1353.0
# Generation  163
# Length of the best route =  1363.0
# Generation  164
# Length of the best route =  1367.0
# Generation  165
# Length of the best route =  1351.0
# Generation  166
# Length of the best route =  1353.0
# Generation  167
# Length of the best route =  1351.0
# Generation  168
# Length of the best route =  1347.0
# Generation  169
# Length of the best route =  1347.0
# Generation  170
# Length of the best route =  1343.0
# Generation  171
# Length of the best route =  1343.0
# Generation  172
# Length of the best route =  1339.0
# Generation  173
# Length of the best route =  1325.0
# Generation  174
# Length of the best route =  1339.0
# Generation  175
# Length of the best route =  1325.0
# Generation  176
# Length of the best route =  1331.0
# Generation  177
# Length of the best route =  1331.0
# Generation  178
# Length of the best route =  1331.0
# Generation  179
# Length of the best route =  1329.0
# Generation  180
# Length of the best route =  1325.0
# Generation  181
# Length of the best route =  1325.0
# Generation  182
# Length of the best route =  1325.0
# Generation  183
# Length of the best route =  1325.0
# Generation  184
# Length of the best route =  1325.0
# Generation  185
# Length of the best route =  1325.0
# Generation  186
# Length of the best route =  1329.0
# Generation  187
# Length of the best route =  1325.0
# Generation  188
# Length of the best route =  1325.0
# Generation  189
# Length of the best route =  1325.0
# Generation  190
# Length of the best route =  1325.0
# Generation  191
# Length of the best route =  1325.0
# Generation  192
# Length of the best route =  1325.0
# Generation  193
# Length of the best route =  1325.0
# Generation  194
# Length of the best route =  1325.0
# Generation  195
# Length of the best route =  1329.0
# Generation  196
# Length of the best route =  1325.0
# Generation  197
# Length of the best route =  1325.0
# Generation  198
# Length of the best route =  1329.0
# Generation  199
# Length of the best route =  1325.0
# Generation  200
# Length of the best route =  1325.0

# %%
import matplotlib.pyplot as plt
import numpy as np
improvement = ga.population_fitness
plt.plot(improvement)
plt.title("Fittness of the population across generations")
plt.xlabel("Generation number")
plt.ylabel("Population's fittness score")
plt.show()

# %%
plt.plot(ga.best_route_across_generation)
plt.title("Best score across generations")
plt.xlabel("Generation number")
plt.ylabel("Best fittness score")
plt.show()

# %%
best = ga.population.take_best_chromosome()
# print(ga.best_route_across_generation)
# print(1.0 / np.max(ga.best_route_across_generation))
scores = np.array(ga.best_route_across_generation)
scores = 1.0 / scores
plt.plot(scores)
plt.title("Best path length across generations")
plt.xlabel("Generation number")
plt.ylabel("Best path length")
plt.show()
print(best.get_products())
print(1.0 / best.get_score())
# Out:
# [ 1  2  7  5 14 16  4  9  8 18 10 15 12 13  6 11  3 17]
# 1325.0

# %%
print(tsp_data.get_distances())
print(tsp_data.get_start_distances())
print(tsp_data.get_end_distances())
# Out:
# [[0, 69, 698, 240, 132, 527, 156, 459, 374, 409, 599, 428, 483, 167, 425, 221, 691, 465], [69, 0, 647, 189, 81, 476, 105, 408, 323, 358, 548, 377, 432, 116, 374, 170, 640, 414], [698, 647, 0, 472, 568, 185, 596, 345, 324, 289, 105, 270, 237, 531, 283, 491, 183, 351], [240, 189, 472, 0, 110, 301, 138, 233, 148, 183, 373, 202, 257, 73, 199, 19, 465, 239], [132, 81, 568, 110, 0, 397, 36, 329, 244, 279, 469, 298, 353, 37, 295, 91, 561, 335], [527, 476, 185, 301, 397, 0, 425, 174, 153, 118, 86, 99, 66, 360, 112, 320, 178, 180], [156, 105, 596, 138, 36, 425, 0, 357, 272, 307, 497, 326, 381, 65, 323, 119, 589, 363], [459, 408, 345, 233, 329, 174, 357, 0, 85, 56, 246, 75, 130, 292, 72, 252, 338, 26], [374, 323, 324, 148, 244, 153, 272, 85, 0, 35, 225, 54, 109, 207, 51, 167, 317, 91], [409, 358, 289, 183, 279, 118, 307, 56, 35, 0, 190, 19, 74, 242, 16, 202, 282, 62], [599, 548, 105, 373, 469, 86, 497, 246, 225, 190, 0, 171, 138, 432, 184, 392, 98, 252], [428, 377, 270, 202, 298, 99, 326, 75, 54, 19, 171, 0, 55, 261, 13, 221, 263, 81], [483, 432, 237, 257, 353, 66, 381, 130, 109, 74, 138, 55, 0, 316, 68, 276, 230, 136], [167, 116, 531, 73, 37, 360, 65, 292, 207, 242, 432, 261, 316, 0, 258, 54, 524, 298], [425, 374, 283, 199, 295, 112, 323, 72, 51, 16, 184, 13, 68, 258, 0, 218, 276, 78], [221, 170, 491, 19, 91, 320, 119, 252, 167, 202, 392, 221, 276, 54, 218, 0, 484, 258], [691, 640, 183, 465, 561, 178, 589, 338, 317, 282, 98, 263, 230, 524, 276, 484, 0, 344], [465, 414, 351, 239, 335, 180, 363, 26, 91, 62, 252, 81, 136, 298, 78, 258, 344, 0]]
# [37, 32, 661, 203, 95, 490, 119, 422, 337, 372, 562, 391, 446, 130, 388, 184, 654, 428]
# [812, 761, 304, 586, 682, 299, 710, 459, 438, 403, 219, 384, 351, 645, 397, 605, 123, 465]

# %% [markdown]
# ### Part 2: Path Finding Through Ant Colony Optimization

# %%
# Please keep your parameters for the ACO easily changeable here
no_ants = 40
no_gen = 40
q = 1000
evap = 0.1
# custom parameters
straight_factor = 1.2
convergence_steps = 6

# Construct the optimization objects
maze = Maze.create_maze("./../data/hard_maze.txt")

spec = PathSpecification.read_coordinates("./../data/hard_coordinates.txt")
aco = AntColonyOptimization(maze, no_ants, no_gen, q, evap, straight_factor, convergence_steps)

# Save starting time
start_time = int(round(time.time() * 1000))

# Run optimization
shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

# Print time taken
print("Time taken: " + str((int(round(time.time() * 1000)) - start_time) / 1000.0))

# Save solution
shortest_route.write_to_file("./../data/hard_solution.txt")

# Print route size
print("Route size: " + str(shortest_route.size()))
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Time taken: 44.048
# Route size: 893

# %%
no_ants = 25
no_gen = 25
q = 1000
evap = 0.2
# custom parameters
straight_factor = 1
convergence_steps = 100

mazes = []
specs = []
maze_types = []

# uncomment this to run graphs on mazes

# mazes = [Maze.create_maze("./../data/easy_maze.txt"), 
#          Maze.create_maze("./../data/medium_maze.txt"), 
#          Maze.create_maze("./../data/hard_maze.txt")]

# specs = [PathSpecification.read_coordinates("./../data/easy_coordinates.txt"),
#          PathSpecification.read_coordinates("./../data/medium_coordinates.txt"),
#          PathSpecification.read_coordinates("./../data/hard_coordinates.txt")]

# maze_types = ["easy", "medium", "hard"]

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):
  
  parameters = [2, 4, 6, 8, 10]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, no_ants, no_gen, q, evap, straight_factor, param)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " conv")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of convergence criterion on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, len(best_routes) + 1)))
  plt.legend()

  plt.show()

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):

  parameters = [10, 15, 20, 25, 40]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, param, no_gen, q, evap, straight_factor, convergence_steps)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " no ants")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of number of ants on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, len(best_routes) + 1)))
  plt.legend()

  plt.show()

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):

  parameters = [10, 15, 20, 25, 40]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, no_ants, param, q, evap, straight_factor, convergence_steps)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " no gen")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of number of generations on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, 41, 4)))
  plt.legend()

  plt.show()

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):

  parameters = [400, 700, 1000, 1500, 2000]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, no_ants, no_gen, param, evap, straight_factor, convergence_steps)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)
    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " Q")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of Q on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, len(best_routes) + 1)))
  plt.legend()

  plt.show()

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):

  parameters = [0.1, 0.2, 0.3, 0.4]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, no_ants, no_gen, q, param, straight_factor, convergence_steps)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " evap")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of evaporation on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, len(best_routes) + 1)))
  plt.legend()

  plt.show()

# %%
for maze, spec, maze_type in zip(mazes, specs, maze_types):

  parameters = [1.0, 1.2, 1.5, 1.7, 2]
  for param in parameters:
    print(maze_type, param)

    start_time = int(round(time.time() * 1000))

    aco = AntColonyOptimization(maze, no_ants, no_gen, q, evap, param, convergence_steps)
    shortest_route, best_routes, avg_routes = aco.find_shortest_route(spec)

    plt.plot(list(range(1, len(best_routes) + 1)), list(map(lambda x: x.size(), best_routes)), label= str(param) + " straight")

  plt.xlabel("number of generations")
  plt.ylabel("length of the path")
  plt.title("Influence of straight factor on performance for " + maze_type + " maze")
  plt.xticks(list(range(1, len(best_routes) + 1)))
  plt.legend()

# %% [markdown]
# ### Synthesis

# %%
# Please keep your parameters for the synthesis part easily changeable here
no_ants = 25
no_gen = 25
q = 1000
evap = 0.2
# custom parameters
straight_factor = 1
convergence_steps = 100

persist_file = "./../tmp/my_tsp"
tsp_path = "./../data/tsp_products.txt"
coordinates = "./../data/hard_coordinates.txt"

# Construct optimization
maze = Maze.create_maze("./../data/hard_maze.txt")
tsp_data = TSPData.read_specification(coordinates, tsp_path)
aco = AntColonyOptimization(maze, no_ants, no_gen, q, evap, straight_factor, convergence_steps)

print("Constructed optimization")

# Run optimization and write to file
tsp_data.calculate_routes(aco)
tsp_data.write_to_file(persist_file)

print("Run optimization and write to file")

# Read from file and print
tsp_data2 = TSPData.read_from_file(persist_file)
print(tsp_data == tsp_data2)

print("Read from file and print")

# Solve TSP using your own paths file
ga = GeneticAlgorithm(generations, population_size)
solution = ga.solve_tsp(tsp_data2)
tsp_data2.write_action_file(solution, "./../data/tsp_solution.txt")

print("Solved TSP using your own paths file")
# Out:
# Ready reading maze file ./../data/hard_maze.txt
# Constructed optimization
